# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("riceClassification.csv")
df
# Out:
#           id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 0          1  4537        92.229316        64.012769      0.719916
# 1          2  2872        74.691881        51.400454      0.725553
# 2          3  3048        76.293164        52.043491      0.731211
# 3          4  3073        77.033628        51.928487      0.738639
# 4          5  3693        85.124785        56.374021      0.749282
# ...      ...   ...              ...              ...           ...
# 18180  18181  5853       148.624571        51.029281      0.939210
# 18181  18182  7585       169.593996        58.141659      0.939398
# 18182  18183  6365       154.777085        52.908085      0.939760
# 18183  18184  5960       151.397924        51.474600      0.940427
# 18184  18185  6134       153.081981        51.590606      0.941500
#
#        ConvexArea  EquivDiameter    Extent  Perimeter  Roundness  \
# 0            4677      76.004525  0.657536    273.085   0.764510
# ...

# %%
df.drop(["id","Class"],axis=1,inplace=True)
df
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0      4537        92.229316        64.012769      0.719916        4677
# 1      2872        74.691881        51.400454      0.725553        3015
# 2      3048        76.293164        52.043491      0.731211        3132
# 3      3073        77.033628        51.928487      0.738639        3157
# 4      3693        85.124785        56.374021      0.749282        3802
# ...     ...              ...              ...           ...         ...
# 18180  5853       148.624571        51.029281      0.939210        6008
# 18181  7585       169.593996        58.141659      0.939398        7806
# 18182  6365       154.777085        52.908085      0.939760        6531
# 18183  5960       151.397924        51.474600      0.940427        6189
# 18184  6134       153.081981        51.590606      0.941500        6283
#
#        EquivDiameter    Extent  Perimeter  Roundness  AspectRation
# ...

# %%
plt.figure(figsize=(20,20))
plt.title("Heatmap Corralation")
sns.heatmap(data=pd.get_dummies(df).corr(),annot=True)
# Out:
# <Axes: title={'center': 'Heatmap Corralation'}>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18185 entries, 0 to 18184
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             18185 non-null  int64
#  1   MajorAxisLength  18185 non-null  float64
#  2   MinorAxisLength  18185 non-null  float64
#  3   Eccentricity     18185 non-null  float64
#  4   ConvexArea       18185 non-null  int64
#  5   EquivDiameter    18185 non-null  float64
#  6   Extent           18185 non-null  float64
#  7   Perimeter        18185 non-null  float64
#  8   Roundness        18185 non-null  float64
#  9   AspectRation     18185 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 1.4 MB

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler()

# %%
scaled_data=scaler.transform(df)

# %%
scaled_data
# Out:
# array([[-1.70363043, -4.80374424,  0.41792669, ..., -2.66177825,
#          0.83958835, -2.66379989],
#        [-2.83847845, -6.22078914, -0.83561103, ..., -4.85731791,
#          1.83721534, -2.6354184 ],
#        [-2.71851854, -6.09140363, -0.77169963, ..., -4.79985991,
#          2.3835873 , -2.60595002],
#        ...,
#        [-0.45768318,  0.25018706, -0.6857677 , ..., -0.31708508,
#         -0.37389933,  0.75045135],
#        [-0.73372729, -0.02285299, -0.82824173, ..., -0.27918653,
#         -1.08116545,  0.7868348 ],
#        [-0.61513056,  0.11322075, -0.81671191, ..., -0.44047571,
#         -0.53075529,  0.84669604]])

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca=pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (18185, 10)

# %%
x_pca.shape
# Out:
# (18185, 2)

# %%
x_pca
# Out:
# array([[ 0.35408319,  8.44244654],
#        [ 2.85491984, 11.01374522],
#        [ 2.48280546, 11.05660034],
#        ...,
#        [ 1.48825346, -0.66273891],
#        [ 2.20307787, -0.80484537],
#        [ 1.96980776, -0.71083772]])

# %%
X=x_pca

# %%
from sklearn.cluster import KMeans
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i,random_state = 42)
    kmeans.fit(X)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('CS')
plt.show()

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
y_kmeans
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
df["clusters"]=y_kmeans
df
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0      4537        92.229316        64.012769      0.719916        4677
# 1      2872        74.691881        51.400454      0.725553        3015
# 2      3048        76.293164        52.043491      0.731211        3132
# 3      3073        77.033628        51.928487      0.738639        3157
# 4      3693        85.124785        56.374021      0.749282        3802
# ...     ...              ...              ...           ...         ...
# 18180  5853       148.624571        51.029281      0.939210        6008
# 18181  7585       169.593996        58.141659      0.939398        7806
# 18182  6365       154.777085        52.908085      0.939760        6531
# 18183  5960       151.397924        51.474600      0.940427        6189
# 18184  6134       153.081981        51.590606      0.941500        6283
#
#        EquivDiameter    Extent  Perimeter  Roundness  AspectRation  clusters
# ...

# %%
y=y_kmeans

# %%
kmeans = KMeans(n_clusters=2, random_state=0)

kmeans.fit(X)

# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))
print('Accuracy score: {0:0.2f}'. format(correct_labels/float(y.size)))
# Out:
# Result: 18185 out of 18185 samples were correctly labeled.
# Accuracy score: 1.00

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.scatter(X[labels == 0, 0], X[labels == 0, 1], label='Class 0', c='blue')
plt.scatter(X[labels == 1, 0], X[labels == 1, 1], label='Class 1', c='red')

# Add labels and title
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Scatter Plot of PCA Components with Different Colors')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.98838225, -0.23280981],
#        [-2.65151654,  0.31045292]])

# %%
cluster_assignments = kmeans.labels_

# %%
plt.scatter(X[:, 0], X[:, 1], c=cluster_assignments, cmap='viridis', edgecolors='k', s=50)
# 'c' parameter assigns colors based on cluster_assignments
# 'cmap' parameter specifies the color map
# 'edgecolors' parameter sets the color of the marker edges
# 's' parameter controls the marker size

# Plot the cluster centers
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='X', s=200, alpha=0.75)
# 'c' parameter sets the color to red
# 'marker' parameter specifies the marker shape (X)
# 's' parameter controls the marker size
# 'alpha' parameter controls the transparency

# Add labels and title
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-means Clustering with Colored Cluster Assignments')

# Show the plot
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
cluster_assignments = kmeans.fit_predict(X)

# %%
silhouette_avg = silhouette_score(X, cluster_assignments)
print(f"Silhouette Score (K-means): {silhouette_avg}")
# Out:
# Silhouette Score (K-means): 0.5647377235520379
