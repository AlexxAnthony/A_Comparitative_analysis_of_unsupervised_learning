# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('riceClassification.csv')

df
# Out:
#           id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 0          1  4537        92.229316        64.012769      0.719916
# 1          2  2872        74.691881        51.400454      0.725553
# 2          3  3048        76.293164        52.043491      0.731211
# 3          4  3073        77.033628        51.928487      0.738639
# 4          5  3693        85.124785        56.374021      0.749282
# ...      ...   ...              ...              ...           ...
# 18180  18181  5853       148.624571        51.029281      0.939210
# 18181  18182  7585       169.593996        58.141659      0.939398
# 18182  18183  6365       154.777085        52.908085      0.939760
# 18183  18184  5960       151.397924        51.474600      0.940427
# 18184  18185  6134       153.081981        51.590606      0.941500
#
#        ConvexArea  EquivDiameter    Extent  Perimeter  Roundness  \
# 0            4677      76.004525  0.657536    273.085   0.764510
# 1            3015      60.471018  0.713009    208.317   0.831658
# 2            3132      62.296341  0.759153    210.012   0.868434
# 3            3157      62.551300  0.783529    210.657   0.870203
# 4            3802      68.571668  0.769375    230.332   0.874743
# ...           ...            ...       ...        ...        ...
# 18180        6008      86.326537  0.498594    332.960   0.663444
# 18181        7806      98.272692  0.647461    385.506   0.641362
# 18182        6531      90.023162  0.561287    342.253   0.682832
# 18183        6189      87.112041  0.492399    343.371   0.635227
# 18184        6283      88.374495  0.489975    338.613   0.672274
#
#        AspectRation  Class
# 0          1.440796      1
# 1          1.453137      1
# 2          1.465950      1
# 3          1.483456      1
# 4          1.510000      1
# ...             ...    ...
# 18180      2.912535      0
# 18181      2.916910      0
# 18182      2.925396      0
# 18183      2.941216      0
# 18184      2.967245      0
#
# [18185 rows x 12 columns]

# %%
df.drop(["id","Class"],axis=1,inplace=True)
df
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0      4537        92.229316        64.012769      0.719916        4677
# 1      2872        74.691881        51.400454      0.725553        3015
# 2      3048        76.293164        52.043491      0.731211        3132
# 3      3073        77.033628        51.928487      0.738639        3157
# 4      3693        85.124785        56.374021      0.749282        3802
# ...     ...              ...              ...           ...         ...
# 18180  5853       148.624571        51.029281      0.939210        6008
# 18181  7585       169.593996        58.141659      0.939398        7806
# 18182  6365       154.777085        52.908085      0.939760        6531
# 18183  5960       151.397924        51.474600      0.940427        6189
# 18184  6134       153.081981        51.590606      0.941500        6283
#
#        EquivDiameter    Extent  Perimeter  Roundness  AspectRation
# 0          76.004525  0.657536    273.085   0.764510      1.440796
# 1          60.471018  0.713009    208.317   0.831658      1.453137
# 2          62.296341  0.759153    210.012   0.868434      1.465950
# 3          62.551300  0.783529    210.657   0.870203      1.483456
# 4          68.571668  0.769375    230.332   0.874743      1.510000
# ...              ...       ...        ...        ...           ...
# 18180      86.326537  0.498594    332.960   0.663444      2.912535
# 18181      98.272692  0.647461    385.506   0.641362      2.916910
# 18182      90.023162  0.561287    342.253   0.682832      2.925396
# 18183      87.112041  0.492399    343.371   0.635227      2.941216
# 18184      88.374495  0.489975    338.613   0.672274      2.967245
#
# [18185 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler()

# %%
scaled_data=scaler.transform(df)
scaled_data
# Out:
# array([[-1.70363043, -4.80374424,  0.41792669, ..., -2.66177825,
#          0.83958835, -2.66379989],
#        [-2.83847845, -6.22078914, -0.83561103, ..., -4.85731791,
#          1.83721534, -2.6354184 ],
#        [-2.71851854, -6.09140363, -0.77169963, ..., -4.79985991,
#          2.3835873 , -2.60595002],
#        ...,
#        [-0.45768318,  0.25018706, -0.6857677 , ..., -0.31708508,
#         -0.37389933,  0.75045135],
#        [-0.73372729, -0.02285299, -0.82824173, ..., -0.27918653,
#         -1.08116545,  0.7868348 ],
#        [-0.61513056,  0.11322075, -0.81671191, ..., -0.44047571,
#         -0.53075529,  0.84669604]])

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca=pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (18185, 10)

# %%
x_pca.shape
# Out:
# (18185, 2)

# %%
x_pca
# Out:
# array([[ 0.35408319,  8.44244654],
#        [ 2.85491984, 11.01374522],
#        [ 2.48280546, 11.05660034],
#        ...,
#        [ 1.48825346, -0.66273891],
#        [ 2.20307787, -0.80484537],
#        [ 1.96980776, -0.71083772]])

# %%
X=x_pca

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5)
cluster_assignments = dbscan.fit_predict(X)

# Plot the data points with colored cluster assignments
plt.scatter(X[:, 0], X[:, 1], c=cluster_assignments, cmap='viridis', edgecolors='k', s=50)

# Add labels and title
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('DBSCAN Clustering with Colored Cluster Assignments')

# Show the plot
plt.show()

# %%
df['cluster'] = dbscan.labels_

df
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0      4537        92.229316        64.012769      0.719916        4677
# 1      2872        74.691881        51.400454      0.725553        3015
# 2      3048        76.293164        52.043491      0.731211        3132
# 3      3073        77.033628        51.928487      0.738639        3157
# 4      3693        85.124785        56.374021      0.749282        3802
# ...     ...              ...              ...           ...         ...
# 18180  5853       148.624571        51.029281      0.939210        6008
# 18181  7585       169.593996        58.141659      0.939398        7806
# 18182  6365       154.777085        52.908085      0.939760        6531
# 18183  5960       151.397924        51.474600      0.940427        6189
# 18184  6134       153.081981        51.590606      0.941500        6283
#
#        EquivDiameter    Extent  Perimeter  Roundness  AspectRation  cluster
# 0          76.004525  0.657536    273.085   0.764510      1.440796       -1
# 1          60.471018  0.713009    208.317   0.831658      1.453137       -1
# 2          62.296341  0.759153    210.012   0.868434      1.465950       -1
# 3          62.551300  0.783529    210.657   0.870203      1.483456       -1
# 4          68.571668  0.769375    230.332   0.874743      1.510000       -1
# ...              ...       ...        ...        ...           ...      ...
# 18180      86.326537  0.498594    332.960   0.663444      2.912535        0
# 18181      98.272692  0.647461    385.506   0.641362      2.916910        0
# 18182      90.023162  0.561287    342.253   0.682832      2.925396        0
# 18183      87.112041  0.492399    343.371   0.635227      2.941216        0
# 18184      88.374495  0.489975    338.613   0.672274      2.967245        0
#
# [18185 rows x 11 columns]

# %%
# accurate epsilon and min samples value

# %%
epsilons = np.linspace(0.01, 1, num=15)
epsilons
# Out:
# array([0.01      , 0.08071429, 0.15142857, 0.22214286, 0.29285714,
#        0.36357143, 0.43428571, 0.505     , 0.57571429, 0.64642857,
#        0.71714286, 0.78785714, 0.85857143, 0.92928571, 1.        ])

# %%
min_samples = np.arange(2, 20, step=3)
min_samples
# Out:
# array([ 2,  5,  8, 11, 14, 17])

# %%
import itertools

combinations = list(itertools.product(epsilons, min_samples))
combinations
# Out:
# [(0.01, 2),
#  (0.01, 5),
#  (0.01, 8),
#  (0.01, 11),
#  (0.01, 14),
#  (0.01, 17),
#  (0.08071428571428571, 2),
#  (0.08071428571428571, 5),
#  (0.08071428571428571, 8),
#  (0.08071428571428571, 11),
#  (0.08071428571428571, 14),
#  (0.08071428571428571, 17),
#  (0.15142857142857144, 2),
#  (0.15142857142857144, 5),
#  (0.15142857142857144, 8),
#  (0.15142857142857144, 11),
#  (0.15142857142857144, 14),
#  (0.15142857142857144, 17),
#  (0.22214285714285714, 2),
#  (0.22214285714285714, 5),
#  (0.22214285714285714, 8),
#  (0.22214285714285714, 11),
#  (0.22214285714285714, 14),
#  (0.22214285714285714, 17),
#  (0.29285714285714287, 2),
#  (0.29285714285714287, 5),
#  (0.29285714285714287, 8),
#  (0.29285714285714287, 11),
#  (0.29285714285714287, 14),
#  (0.29285714285714287, 17),
#  (0.3635714285714286, 2),
#  (0.3635714285714286, 5),
#  (0.3635714285714286, 8),
#  (0.3635714285714286, 11),
#  (0.3635714285714286, 14),
#  (0.3635714285714286, 17),
#  (0.4342857142857143, 2),
#  (0.4342857142857143, 5),
#  (0.4342857142857143, 8),
#  (0.4342857142857143, 11),
#  (0.4342857142857143, 14),
#  (0.4342857142857143, 17),
#  (0.505, 2),
#  (0.505, 5),
#  (0.505, 8),
#  (0.505, 11),
#  (0.505, 14),
#  (0.505, 17),
#  (0.5757142857142857, 2),
#  (0.5757142857142857, 5),
#  (0.5757142857142857, 8),
#  (0.5757142857142857, 11),
#  (0.5757142857142857, 14),
#  (0.5757142857142857, 17),
#  (0.6464285714285715, 2),
#  (0.6464285714285715, 5),
#  (0.6464285714285715, 8),
#  (0.6464285714285715, 11),
#  (0.6464285714285715, 14),
#  (0.6464285714285715, 17),
#  (0.7171428571428572, 2),
#  (0.7171428571428572, 5),
#  (0.7171428571428572, 8),
#  (0.7171428571428572, 11),
#  (0.7171428571428572, 14),
#  (0.7171428571428572, 17),
#  (0.7878571428571429, 2),
#  (0.7878571428571429, 5),
#  (0.7878571428571429, 8),
#  (0.7878571428571429, 11),
#  (0.7878571428571429, 14),
#  (0.7878571428571429, 17),
#  (0.8585714285714285, 2),
#  (0.8585714285714285, 5),
#  (0.8585714285714285, 8),
#  (0.8585714285714285, 11),
#  (0.8585714285714285, 14),
#  (0.8585714285714285, 17),
#  (0.9292857142857143, 2),
#  (0.9292857142857143, 5),
#  (0.9292857142857143, 8),
#  (0.9292857142857143, 11),
#  (0.9292857142857143, 14),
#  (0.9292857142857143, 17),
#  (1.0, 2),
#  (1.0, 5),
#  (1.0, 8),
#  (1.0, 11),
#  (1.0, 14),
#  (1.0, 17)]

# %%
N = len(combinations)
N
# Out:
# 90

# %%
from sklearn.metrics import silhouette_score as ss

# %%
def get_scores_and_labels(combinations, X):
  scores = []
  all_labels_list = []

  for i, (eps, num_samples) in enumerate(combinations):
    dbscan_cluster_model = DBSCAN(eps=eps, min_samples=num_samples).fit(X)
    labels = dbscan_cluster_model.labels_
    labels_set = set(labels)
    num_clusters = len(labels_set)
    if -1 in labels_set:
      num_clusters -= 1
    
    if (num_clusters < 2) or (num_clusters > 50):
      scores.append(-10)
      all_labels_list.append('bad')
      c = (eps, num_samples)
      print(f"Combination {c} on iteration {i+1} of {N} has {num_clusters} clusters. Moving on")
      continue
    
    scores.append(ss(X, labels))
    all_labels_list.append(labels)
    print(f"Index: {i}, Score: {scores[-1]}, Labels: {all_labels_list[-1]}, NumClusters: {num_clusters}")

  best_index = np.argmax(scores)
  best_parameters = combinations[best_index]
  best_labels = all_labels_list[best_index]
  best_score = scores[best_index]

  return {'best_epsilon': best_parameters[0],
          'best_min_samples': best_parameters[1], 
          'best_labels': best_labels,
          'best_score': best_score}

best_dict = get_scores_and_labels(combinations, X)
# Out:
# Combination (0.01, 2) on iteration 1 of 90 has 1522 clusters. Moving on
# Index: 1, Score: -0.14680092145403345, Labels: [-1 -1 -1 ... -1 -1 -1], NumClusters: 3
# Combination (0.01, 8) on iteration 3 of 90 has 0 clusters. Moving on
# Combination (0.01, 11) on iteration 4 of 90 has 0 clusters. Moving on
# Combination (0.01, 14) on iteration 5 of 90 has 0 clusters. Moving on
# Combination (0.01, 17) on iteration 6 of 90 has 0 clusters. Moving on
# Combination (0.08071428571428571, 2) on iteration 7 of 90 has 448 clusters. Moving on
# Combination (0.08071428571428571, 5) on iteration 8 of 90 has 137 clusters. Moving on
# Combination (0.08071428571428571, 8) on iteration 9 of 90 has 75 clusters. Moving on
# Combination (0.08071428571428571, 11) on iteration 10 of 90 has 61 clusters. Moving on
# Index: 10, Score: -0.4675302964455309, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 39
# Index: 11, Score: -0.5315025655105902, Labels: [-1 -1 -1 ...  1  1  1], NumClusters: 43
# Combination (0.15142857142857144, 2) on iteration 13 of 90 has 183 clusters. Moving on
# Index: 13, Score: -0.41710726552892874, Labels: [-1 -1 -1 ...  3  3  3], NumClusters: 29
# Index: 14, Score: -0.2521431086789448, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 12
# Index: 15, Score: -0.031232181326960814, Labels: [-1 -1 -1 ...  2  2  2], NumClusters: 15
# Index: 16, Score: -0.21392158107263148, Labels: [-1 -1 -1 ...  1  1  1], NumClusters: 15
# Index: 17, Score: -0.09056229000749214, Labels: [-1 -1 -1 ...  3  3  3], NumClusters: 11
# Combination (0.22214285714285714, 2) on iteration 19 of 90 has 91 clusters. Moving on
# Index: 19, Score: -0.1485809645029252, Labels: [-1 -1 -1 ...  8  8  8], NumClusters: 20
# Index: 20, Score: 0.12076296534856462, Labels: [-1 -1 -1 ...  2  2  2], NumClusters: 10
# Index: 21, Score: -0.01860466916521529, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 7
# Index: 22, Score: 0.006865997166385879, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 4
# Index: 23, Score: 0.19880707936403452, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Index: 24, Score: -0.27799317170638543, Labels: [-1 -1  0 ...  9  9  9], NumClusters: 43
# Index: 25, Score: 0.01987225599942983, Labels: [-1 -1 -1 ...  7  7  7], NumClusters: 16
# Index: 26, Score: 0.02677260170708621, Labels: [-1 -1 -1 ...  5  5  5], NumClusters: 11
# Index: 27, Score: 0.03741693229742956, Labels: [-1 -1 -1 ...  2  2  2], NumClusters: 5
# Index: 28, Score: 0.39271435258376547, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Index: 29, Score: 0.3833865121109286, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Index: 30, Score: -0.25093165753533925, Labels: [-1 -1  0 ...  4  4  4], NumClusters: 25
# Index: 31, Score: 0.41449911005080836, Labels: [-1 -1 -1 ...  3  3  3], NumClusters: 6
# Index: 32, Score: 0.12071345421232522, Labels: [-1 -1 -1 ...  2  2  2], NumClusters: 9
# Index: 33, Score: 0.2711914784108729, Labels: [-1 -1 -1 ...  3  3  3], NumClusters: 7
# Index: 34, Score: 0.202166077121839, Labels: [-1 -1 -1 ...  2  2  2], NumClusters: 4
# Index: 35, Score: 0.40926797646595026, Labels: [-1 -1 -1 ...  1  1  1], NumClusters: 2
# Index: 36, Score: -0.1857101023897848, Labels: [-1  0  0 ...  3  3  3], NumClusters: 16
# Index: 37, Score: 0.41513572428856993, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Index: 38, Score: 0.485030981309231, Labels: [-1 -1 -1 ...  1  1  1], NumClusters: 3
# Index: 39, Score: 0.23943768731731954, Labels: [-1 -1 -1 ...  1  1  1], NumClusters: 5
# Index: 40, Score: 0.35661922875633234, Labels: [-1 -1 -1 ...  2  2  2], NumClusters: 4
# Index: 41, Score: 0.4378294350141695, Labels: [-1 -1 -1 ...  1  1  1], NumClusters: 2
# Index: 42, Score: 0.33567161516250554, Labels: [-1  0  0 ...  3  3  3], NumClusters: 10
# Index: 43, Score: 0.40070439915306816, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 4
# Index: 44, Score: 0.5055955361656062, Labels: [-1 -1 -1 ...  1  1  1], NumClusters: 2
# Index: 45, Score: 0.5061978605716175, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Index: 46, Score: 0.4236225417588799, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Combination (0.505, 17) on iteration 48 of 90 has 1 clusters. Moving on
# Index: 48, Score: 0.428982618218201, Labels: [-1  0  0 ...  2  2  2], NumClusters: 6
# Index: 49, Score: 0.5689712339166728, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Combination (0.5757142857142857, 8) on iteration 51 of 90 has 1 clusters. Moving on
# Index: 51, Score: 0.5011012499691617, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 3
# Combination (0.5757142857142857, 14) on iteration 53 of 90 has 1 clusters. Moving on
# Combination (0.5757142857142857, 17) on iteration 54 of 90 has 1 clusters. Moving on
# Index: 54, Score: 0.3356285885854655, Labels: [-1  0  0 ...  1  1  1], NumClusters: 6
# Index: 55, Score: 0.5779174303346354, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Combination (0.6464285714285715, 8) on iteration 57 of 90 has 1 clusters. Moving on
# Combination (0.6464285714285715, 11) on iteration 58 of 90 has 1 clusters. Moving on
# Combination (0.6464285714285715, 14) on iteration 59 of 90 has 1 clusters. Moving on
# Combination (0.6464285714285715, 17) on iteration 60 of 90 has 1 clusters. Moving on
# Index: 60, Score: 0.3313160104687707, Labels: [-1  0  0 ...  1  1  1], NumClusters: 5
# Index: 61, Score: 0.5783392670802998, Labels: [-1 -1 -1 ...  0  0  0], NumClusters: 2
# Combination (0.7171428571428572, 8) on iteration 63 of 90 has 1 clusters. Moving on
# Combination (0.7171428571428572, 11) on iteration 64 of 90 has 1 clusters. Moving on
# Combination (0.7171428571428572, 14) on iteration 65 of 90 has 1 clusters. Moving on
# Combination (0.7171428571428572, 17) on iteration 66 of 90 has 1 clusters. Moving on
# Index: 66, Score: 0.3033956803596119, Labels: [0 1 1 ... 0 0 0], NumClusters: 4
# Combination (0.7878571428571429, 5) on iteration 68 of 90 has 1 clusters. Moving on
# Combination (0.7878571428571429, 8) on iteration 69 of 90 has 1 clusters. Moving on
# Combination (0.7878571428571429, 11) on iteration 70 of 90 has 1 clusters. Moving on
# Combination (0.7878571428571429, 14) on iteration 71 of 90 has 1 clusters. Moving on
# Combination (0.7878571428571429, 17) on iteration 72 of 90 has 1 clusters. Moving on
# Index: 72, Score: 0.3072813987557283, Labels: [0 1 1 ... 0 0 0], NumClusters: 3
# Combination (0.8585714285714285, 5) on iteration 74 of 90 has 1 clusters. Moving on
# Combination (0.8585714285714285, 8) on iteration 75 of 90 has 1 clusters. Moving on
# Combination (0.8585714285714285, 11) on iteration 76 of 90 has 1 clusters. Moving on
# Combination (0.8585714285714285, 14) on iteration 77 of 90 has 1 clusters. Moving on
# Combination (0.8585714285714285, 17) on iteration 78 of 90 has 1 clusters. Moving on
# Index: 78, Score: 0.3588329445132746, Labels: [0 1 1 ... 0 0 0], NumClusters: 3
# Combination (0.9292857142857143, 5) on iteration 80 of 90 has 1 clusters. Moving on
# Combination (0.9292857142857143, 8) on iteration 81 of 90 has 1 clusters. Moving on
# Combination (0.9292857142857143, 11) on iteration 82 of 90 has 1 clusters. Moving on
# Combination (0.9292857142857143, 14) on iteration 83 of 90 has 1 clusters. Moving on
# Combination (0.9292857142857143, 17) on iteration 84 of 90 has 1 clusters. Moving on
# Index: 84, Score: 0.3588329445132746, Labels: [0 1 1 ... 0 0 0], NumClusters: 3
# Combination (1.0, 5) on iteration 86 of 90 has 1 clusters. Moving on
# Combination (1.0, 8) on iteration 87 of 90 has 1 clusters. Moving on
# Combination (1.0, 11) on iteration 88 of 90 has 1 clusters. Moving on
# Combination (1.0, 14) on iteration 89 of 90 has 1 clusters. Moving on
# Combination (1.0, 17) on iteration 90 of 90 has 1 clusters. Moving on

# %%
best_dict
# Out:
# {'best_epsilon': 0.7171428571428572,
#  'best_min_samples': 5,
#  'best_labels': array([-1, -1, -1, ...,  0,  0,  0]),
#  'best_score': 0.5783392670802998}

# %%
dbscan = DBSCAN(eps=0.7171428571428572, min_samples=5)
cluster_assignments = dbscan.fit_predict(X)

# Plot the data points with colored cluster assignments
plt.scatter(X[:, 0], X[:, 1], c=cluster_assignments, cmap='viridis', edgecolors='k', s=50)

# Add labels and title
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('DBSCAN Clustering with Colored Cluster Assignments')

# Show the plot
plt.show()

# %%
df['cluster'] = best_dict['best_labels']

df['cluster'].value_counts()
# Out:
# cluster
#  0    18155
# -1       23
#  1        7
# Name: count, dtype: int64

# %%
cluster_assignments = dbscan.fit_predict(X)

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_avg = silhouette_score(X, cluster_assignments)
print(f"Silhouette Score (DBSCAN): {silhouette_avg}")
# Out:
# Silhouette Score (DBSCAN): 0.5783392670802998
